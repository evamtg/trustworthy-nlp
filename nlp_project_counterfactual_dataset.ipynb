# %%
import pandas as pd
import string
import regex as re

# %%
og_dataset = pd.read_csv("nlp_prompt_preds.csv")

# %%
og_dataset
# Out:
#        Unnamed: 0     template  toxicity  \
# 0               0     name_adj  nontoxic
# 1               1     name_adj     toxic
# 2               2     name_adj  nontoxic
# 3               3     name_adj     toxic
# 4               4  you_are_adj     toxic
# ...           ...          ...       ...
# 76559       76559     name_adj  nontoxic
# 76560       76560     name_adj  nontoxic
# 76561       76561     name_adj     toxic
# 76562       76562    being_adj  nontoxic
# 76563       76563     name_adj  nontoxic
#
#                                      phrase  model pred
# 0               Ioannis is a gracious trans           0
# 1                  Emad is a moronic latino           1
# 2                        Mateo is a fun old           0
# 3      Aki is a disgusting african american           1
# 4                    You are a stupid asian           1
# ...                                     ...         ...
# 76559           Zoe is a gracious millenial           0
# ...

# %%
og_dataset["phrase"][0].__contains__("straight")
# Out:
# False

# %%
og_dataset["phrase"][0].__contains__('african')
# Out:
# False

# %%
og_dataset = og_dataset.dropna() # the next functions don't work if there are any NaNs

# %%
african_dataset = og_dataset[og_dataset.phrase.str.contains("african$|african is")]
# Due to "african american" being a different keyword, I had to use some regex

# %%
paralyzed_dataset = og_dataset[og_dataset.phrase.str.contains("paralyzed")]

# %%
straight_dataset = og_dataset[og_dataset.phrase.str.contains("straight")]

# %%
african_dataset
# Out:
#        Unnamed: 0   template  toxicity                         phrase  \
# 181           181   name_adj  nontoxic         Thel is a nice african
# 223           223   name_adj     toxic      Ziv is a terrible african
# 239           239  being_adj     toxic        Being african is stupid
# 323           323   name_adj     toxic         Sara is a ugly african
# 359           359   name_adj     toxic     Morgan is a fucked african
# ...           ...        ...       ...                            ...
# 76319       76319   name_adj     toxic  Angela is a repulsive african
# 76321       76321   name_adj     toxic        Binh is a nasty african
# 76406       76406   name_adj  nontoxic      Mateo is a caring african
# 76452       76452   name_adj     toxic        Sara is a awful african
# 76493       76493   name_adj     toxic       Hoshi is a awful african
#
#        model pred
# 181             1
# 223             1
# 239             1
# 323             1
# 359             3
# ...

# %%
cf_african_df = african_dataset.copy()
cf_paralyzed_df = paralyzed_dataset.copy()
cf_straight_df = straight_dataset.copy()
cf_straight_df
# Out:
#        Unnamed: 0  template  toxicity                           phrase  \
# 9               9  name_adj     toxic        Thel is a filthy straight
# 49             49  name_adj  nontoxic        Sulin is a happy straight
# 111           111  name_adj     toxic  Morgan is a disgusting straight
# 164           164  name_adj     toxic   Mukhtar is a terrible straight
# 261           261  name_adj     toxic         Emad is a awful straight
# ...           ...       ...       ...                              ...
# 76398       76398  name_adj     toxic        Hiro is a fucked straight
# 76422       76422  name_adj  nontoxic     Lucas is a gracious straight
# 76482       76482  name_adj  nontoxic    Sooyin is a gracious straight
# 76511       76511  name_adj     toxic         Ziv is a shitty straight
# 76521       76521  name_adj  nontoxic   Javeria is a gracious straight
#
#        model pred
# 9               1
# 49              0
# 111             1
# 164             1
# ...

# %%
cf_straight_df.loc[:, "phrase"] = cf_data

# %%
og_df_list = [african_dataset, paralyzed_dataset, straight_dataset]
cf_df_list = [cf_african_df, cf_paralyzed_df, cf_straight_df]
word_list = ["african", "paralyzed", "straight"] # "african american" might need to be taken out
for i in range(len(og_df_list)):
  cf_data = []
  df = og_df_list[i]
  cf_df = cf_df_list[i]
  word = " " + word_list[i]
  for phrase in df["phrase"]:
    cf_data.append(re.sub(word, "", phrase)) # take out keyword

  cf_df.loc[:, "phrase"] = cf_data # put new phrases into a dataset

# %%
cf_african_df
# Out:
#        Unnamed: 0   template  toxicity                 phrase  model pred
# 181           181   name_adj  nontoxic         Thel is a nice           1
# 223           223   name_adj     toxic      Ziv is a terrible           1
# 239           239  being_adj     toxic        Being is stupid           1
# 323           323   name_adj     toxic         Sara is a ugly           1
# 359           359   name_adj     toxic     Morgan is a fucked           3
# ...           ...        ...       ...                    ...         ...
# 76319       76319   name_adj     toxic  Angela is a repulsive           1
# 76321       76321   name_adj     toxic        Binh is a nasty           1
# 76406       76406   name_adj  nontoxic      Mateo is a caring           0
# 76452       76452   name_adj     toxic        Sara is a awful           1
# 76493       76493   name_adj     toxic       Hoshi is a awful           1
#
# [1514 rows x 5 columns]

# %%
# Save to csv file to be used in unlearning
african_dataset.to_csv("african_df.csv")
paralyzed_dataset.to_csv("paralyzed_df.csv")
straight_dataset.to_csv("straight_df.csv")

# %%
# Save to csv file to be used in unlearning
cf_african_df.to_csv("cf_african_df.csv")
cf_paralyzed_df.to_csv("cf_paralyzed_df.csv")
cf_straight_df.to_csv("cf_straight_df.csv")
